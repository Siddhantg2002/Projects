# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantg2002/Projects/blob/main/Breast_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --use-deprecated=legacy-resolver pycaret[full]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret[full] in /usr/local/lib/python3.9/dist-packages (3.0.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.7.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.6.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.3.7)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (5.8.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (6.1.0)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.5)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.1.2)
# Requirement already satisfied: schemdraw>=0.14 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.16)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.2.2)
# Requirement already satisfied: pyod>=1.0.8 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.0.9)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (7.9.0)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.4.4)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (7.7.1)
# Requirement already satisfied: wurlitzer; platform_system != "Windows" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.0.3)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.3.5)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.1.2)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.1.2)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.2.1)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.56.4)
# Requirement already satisfied: sktime>=0.16.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.16.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (5.13.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.22.4)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (5.9.4)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.27.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.2.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.10.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.2.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.8.3.2)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.2.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.13.5)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.1.0)
# Requirement already satisfied: statsforecast>=0.5.5; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.5.0)
# Requirement already satisfied: moto>=3.0.7; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (4.1.6)
# Requirement already satisfied: catboost>=0.23.2; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.1.1)
# Requirement already satisfied: scikit-learn-intelex>=2023.0.1; (platform_machine == "x86_64" or platform_machine == "AMD64") and extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2023.1.0)
# Requirement already satisfied: pytest>=7.0.1; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (7.2.2)
# Requirement already satisfied: mlxtend>=0.19.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.22.0)
# Requirement already satisfied: optuna>=3.0.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.1.0)
# Requirement already satisfied: evidently>=0.1.45.dev0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.2.8)
# Requirement already satisfied: codecov>=2.1.12; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.1.12)
# Requirement already satisfied: fairlearn==0.7.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.7.0)
# Requirement already satisfied: flask>=2.0.3; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.2.3)
# Requirement already satisfied: fugue[dask]>=0.8.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.8.3)
# Requirement already satisfied: mlflow<2.0.0,>=1.24.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.30.0)
# Requirement already satisfied: pandas-profiling>=3.1.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.2.0)
# Requirement already satisfied: m2cgen>=0.9.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.10.0)
# Requirement already satisfied: shap>=0.38.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.41.0)
# Requirement already satisfied: explainerdashboard>=0.3.8; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.4.2.1)
# Requirement already satisfied: ray[tune]>=1.0.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.3.1)
# Requirement already satisfied: scikit-optimize>=0.9.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.9.0)
# Requirement already satisfied: xgboost>=1.1.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.7.4)
# Requirement already satisfied: deepchecks>=0.9.2; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.13.0)
# Requirement already satisfied: umap-learn>=0.5.2; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.5.3)
# Requirement already satisfied: kmodes>=0.11.1; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.12.2)
# Requirement already satisfied: hyperopt>=0.2.7; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.2.7)
# Requirement already satisfied: uvicorn>=0.17.6; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.21.1)
# Requirement already satisfied: boto3>=1.24.56; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (1.26.104)
# Requirement already satisfied: gradio>=2.8.10; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (3.24.1)
# Requirement already satisfied: dash[testing]; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (2.9.2)
# Requirement already satisfied: fastapi>=0.75.0; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.95.0)
# Requirement already satisfied: tune-sklearn>=0.2.1; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.4.5)
# Requirement already satisfied: interpret>=0.2.7; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.3.2)
# Requirement already satisfied: autoviz>=0.1.36; extra == "full" in /usr/local/lib/python3.9/dist-packages (from pycaret[full]) (0.1.58)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (4.39.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret[full]) (1.0.7)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders>=2.4.0->pycaret[full]) (0.5.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret[full]) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret[full]) (5.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret[full]) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret[full]) (4.3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.12.0->pycaret[full]) (3.15.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (67.6.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (1.26.15)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (0.29.33)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0->pycaret[full]) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from pyod>=1.0.8->pycaret[full]) (1.16.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret[full]) (2.14.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret[full]) (2022.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.6.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.0.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->pycaret[full]) (0.40.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.55.0->pycaret[full]) (0.39.1)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.9/dist-packages (from sktime>=0.16.1->pycaret[full]) (1.2.13)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->pycaret[full]) (8.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret[full]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret[full]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret[full]) (3.4)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret[full]) (0.0.9)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret[full]) (0.4.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret[full]) (3.8.9)
# Requirement already satisfied: responses>=0.13.0 in /usr/local/lib/python3.9/dist-packages (from moto>=3.0.7; extra == "full"->pycaret[full]) (0.23.1)
# Requirement already satisfied: botocore>=1.12.201 in /usr/local/lib/python3.9/dist-packages (from moto>=3.0.7; extra == "full"->pycaret[full]) (1.29.104)
# Requirement already satisfied: cryptography>=3.3.1 in /usr/local/lib/python3.9/dist-packages (from moto>=3.0.7; extra == "full"->pycaret[full]) (39.0.2)
# Requirement already satisfied: werkzeug!=2.2.0,!=2.2.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from moto>=3.0.7; extra == "full"->pycaret[full]) (2.2.3)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.9/dist-packages (from moto>=3.0.7; extra == "full"->pycaret[full]) (0.13.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost>=0.23.2; extra == "full"->pycaret[full]) (0.20.1)
# Requirement already satisfied: daal4py==2023.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn-intelex>=2023.0.1; (platform_machine == "x86_64" or platform_machine == "AMD64") and extra == "full"->pycaret[full]) (2023.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest>=7.0.1; extra == "full"->pycaret[full]) (22.2.0)
# Requirement already satisfied: tomli>=1.0.0; python_version < "3.11" in /usr/local/lib/python3.9/dist-packages (from pytest>=7.0.1; extra == "full"->pycaret[full]) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8; python_version < "3.11" in /usr/local/lib/python3.9/dist-packages (from pytest>=7.0.1; extra == "full"->pycaret[full]) (1.1.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest>=7.0.1; extra == "full"->pycaret[full]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest>=7.0.1; extra == "full"->pycaret[full]) (1.0.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from optuna>=3.0.0; extra == "full"->pycaret[full]) (6.7.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna>=3.0.0; extra == "full"->pycaret[full]) (6.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=3.0.0; extra == "full"->pycaret[full]) (1.4.47)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from optuna>=3.0.0; extra == "full"->pycaret[full]) (0.9.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=3.0.0; extra == "full"->pycaret[full]) (1.10.2)
# Requirement already satisfied: nltk>=3.6.7 in /usr/local/lib/python3.9/dist-packages (from evidently>=0.1.45.dev0; extra == "full"->pycaret[full]) (3.8.1)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.9/dist-packages (from evidently>=0.1.45.dev0; extra == "full"->pycaret[full]) (1.10.7)
# Requirement already satisfied: coverage in /usr/local/lib/python3.9/dist-packages (from codecov>=2.1.12; extra == "full"->pycaret[full]) (7.2.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from flask>=2.0.3; extra == "full"->pycaret[full]) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from flask>=2.0.3; extra == "full"->pycaret[full]) (2.1.2)
# Requirement already satisfied: sqlglot in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (11.4.5)
# Requirement already satisfied: pyarrow>=0.15.1 in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (9.0.0)
# Requirement already satisfied: qpd>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (0.4.0)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (0.1.6)
# Requirement already satisfied: adagio>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (0.2.4)
# Requirement already satisfied: triad>=0.8.4 in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (0.8.4)
# Requirement already satisfied: dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask" in /usr/local/lib/python3.9/dist-packages (from fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (2022.12.1)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (0.4)
# Requirement already satisfied: prometheus-flask-exporter<1 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (0.22.3)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (0.17.6)
# Requirement already satisfied: gunicorn<21; platform_system != "Windows" in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (20.1.0)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (3.1.31)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (1.2.4)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (3.19.6)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (0.4.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.2.0)
# Requirement already satisfied: multimethod>=1.4 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (1.9.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.7.4)
# Requirement already satisfied: missingno>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.5.2)
# Requirement already satisfied: seaborn>=0.10.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.12.2)
# Requirement already satisfied: phik>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.12.3)
# Requirement already satisfied: htmlmin>=0.1.12 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (0.1.12)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.9/dist-packages (from shap>=0.38.0; extra == "full"->pycaret[full]) (0.0.7)
# Requirement already satisfied: flask-simplelogin in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (0.1.1)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (1.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (1.4.1)
# Requirement already satisfied: dash-auth in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (2.0.0)
# Requirement already satisfied: dtreeviz>=2.1 in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (2.2.0)
# Requirement already satisfied: waitress in /usr/local/lib/python3.9/dist-packages (from explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (2.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (3.10.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.0.5)
# Requirement already satisfied: grpcio>=1.32.0; python_version < "3.10" and sys_platform != "darwin" in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.51.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.3.3)
# Requirement already satisfied: virtualenv>=20.0.24 in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (20.21.0)
# Requirement already satisfied: tabulate; extra == "tune" in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (0.8.10)
# Requirement already satisfied: tensorboardX>=1.9; extra == "tune" in /usr/local/lib/python3.9/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (2.6)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize>=0.9.0; extra == "full"->pycaret[full]) (21.10.1)
# Requirement already satisfied: jsonpickle>=2 in /usr/local/lib/python3.9/dist-packages (from deepchecks>=0.9.2; extra == "full"->pycaret[full]) (3.0.1)
# Requirement already satisfied: pyzmq<24.0.0 in /usr/local/lib/python3.9/dist-packages (from deepchecks>=0.9.2; extra == "full"->pycaret[full]) (23.2.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from deepchecks>=0.9.2; extra == "full"->pycaret[full]) (4.11.2)
# Requirement already satisfied: PyNomaly>=0.3.3 in /usr/local/lib/python3.9/dist-packages (from deepchecks>=0.9.2; extra == "full"->pycaret[full]) (0.3.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from deepchecks>=0.9.2; extra == "full"->pycaret[full]) (4.5.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.2; extra == "full"->pycaret[full]) (0.5.8)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7; extra == "full"->pycaret[full]) (0.18.3)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7; extra == "full"->pycaret[full]) (0.10.9.7)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7; extra == "full"->pycaret[full]) (3.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn>=0.17.6; extra == "full"->pycaret[full]) (0.14.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3>=1.24.56; extra == "full"->pycaret[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3>=1.24.56; extra == "full"->pycaret[full]) (0.6.0)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (4.2.2)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (23.1.0)
# Requirement already satisfied: gradio-client>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.0.5)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.25.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.3.3)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (3.8.4)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (11.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.23.3)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (0.13.3)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (2.2.0)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.9/dist-packages (from gradio>=2.8.10; extra == "full"->pycaret[full]) (2.10.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (2.0.0)
# Requirement already satisfied: selenium<=4.2.0,>=3.141.0; extra == "testing" in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.2.0)
# Requirement already satisfied: multiprocess>=0.70.12; extra == "testing" in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.70.14)
# Requirement already satisfied: lxml>=4.6.2; extra == "testing" in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.9.2)
# Requirement already satisfied: percy>=2.0.2; extra == "testing" in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (2.0.2)
# Requirement already satisfied: dash-testing-stub>=0.0.2; extra == "testing" in /usr/local/lib/python3.9/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.0.2)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi>=0.75.0; extra == "full"->pycaret[full]) (0.26.1)
# Requirement already satisfied: interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2 in /usr/local/lib/python3.9/dist-packages (from interpret>=0.2.7; extra == "full"->pycaret[full]) (0.3.2)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (2023.3.0)
# Requirement already satisfied: pyamg in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (4.2.3)
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (2.4.3)
# Requirement already satisfied: textblob in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.17.1)
# Requirement already satisfied: panel~=0.12.6 in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.12.7)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (2.0.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (2.2.0)
# Requirement already satisfied: hvplot>=0.7.3 in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.8.3)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.8.2.2)
# Requirement already satisfied: holoviews>=1.14.6 in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.15.4)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.9/dist-packages (from autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret[full]) (3.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.19.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.5.0->pycaret[full]) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.5.0->pycaret[full]) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.5.0->pycaret[full]) (0.2.6)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[full]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[full]) (6.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret[full]) (1.15.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret[full]) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret[full]) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret[full]) (1.5.6)
# Requirement already satisfied: types-PyYAML in /usr/local/lib/python3.9/dist-packages (from responses>=0.13.0->moto>=3.0.7; extra == "full"->pycaret[full]) (6.0.12.9)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.1->moto>=3.0.7; extra == "full"->pycaret[full]) (1.15.1)
# Requirement already satisfied: daal==2023.1.0 in /usr/local/lib/python3.9/dist-packages (from daal4py==2023.1.0->scikit-learn-intelex>=2023.0.1; (platform_machine == "x86_64" or platform_machine == "AMD64") and extra == "full"->pycaret[full]) (2023.1.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.0.0; extra == "full"->pycaret[full]) (2.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna>=3.0.0; extra == "full"->pycaret[full]) (1.2.4)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk>=3.6.7->evidently>=0.1.45.dev0; extra == "full"->pycaret[full]) (2022.10.31)
# Requirement already satisfied: antlr4-python3-runtime<4.12,>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from qpd>=0.4.0->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (4.11.1)
# Requirement already satisfied: fs in /usr/local/lib/python3.9/dist-packages (from triad>=0.8.4->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (2.4.16)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.9/dist-packages (from dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (0.12.0)
# Requirement already satisfied: distributed==2022.12.1; extra == "distributed" in /usr/local/lib/python3.9/dist-packages (from dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (2022.12.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from prometheus-flask-exporter<1->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (0.16.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (2.6.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (3.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from gitpython<4,>=2.1.0->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (4.0.10)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (1.5.1)
# Requirement already satisfied: imagehash; extra == "type_image_path" in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (4.3.1)
# Requirement already satisfied: WTForms>=2.1 in /usr/local/lib/python3.9/dist-packages (from flask-simplelogin->explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (3.0.1)
# Requirement already satisfied: Flask-WTF<0.16.0,>=0.15.1 in /usr/local/lib/python3.9/dist-packages (from flask-simplelogin->explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (0.15.1)
# Requirement already satisfied: colour in /usr/local/lib/python3.9/dist-packages (from dtreeviz>=2.1->explainerdashboard>=0.3.8; extra == "full"->pycaret[full]) (0.1.5)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (0.3.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->deepchecks>=0.9.2; extra == "full"->pycaret[full]) (2.4)
# Requirement already satisfied: python-utils in /usr/local/lib/python3.9/dist-packages (from PyNomaly>=0.3.3->deepchecks>=0.9.2; extra == "full"->pycaret[full]) (3.5.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio>=2.8.10; extra == "full"->pycaret[full]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio>=2.8.10; extra == "full"->pycaret[full]) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio>=2.8.10; extra == "full"->pycaret[full]) (4.0.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio>=2.8.10; extra == "full"->pycaret[full]) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio>=2.8.10; extra == "full"->pycaret[full]) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio>=2.8.10; extra == "full"->pycaret[full]) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio>=2.8.10; extra == "full"->pycaret[full]) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1; extra == "linkify" in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio>=2.8.10; extra == "full"->pycaret[full]) (2.0.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.9/dist-packages (from selenium<=4.2.0,>=3.141.0; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (0.10.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.9/dist-packages (from selenium<=4.2.0,>=3.141.0; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (0.22.0)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from multiprocess>=0.70.12; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (0.3.6)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from starlette<0.27.0,>=0.26.1->fastapi>=0.75.0; extra == "full"->pycaret[full]) (3.6.2)
# Requirement already satisfied: treeinterpreter>=0.2.2; extra == "treeinterpreter" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (0.2.3)
# Requirement already satisfied: skope-rules>=1.0.1; extra == "skoperules" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (1.0.1)
# Requirement already satisfied: SALib>=1.3.3; extra == "sensitivity" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (1.4.7)
# Requirement already satisfied: lime>=0.1.1.33; extra == "lime" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (0.2.0.1)
# Requirement already satisfied: gevent>=1.3.6; extra == "dash" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (22.10.2)
# Requirement already satisfied: dash-cytoscape>=0.1.1; extra == "dash" in /usr/local/lib/python3.9/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (0.3.0)
# Requirement already satisfied: param>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.13.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (6.0.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.9/dist-packages (from panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (2.2.1)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.9/dist-packages (from panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.5.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (3.4.2)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.9/dist-packages (from hvplot>=0.7.3->autoviz>=0.1.36; extra == "full"->pycaret[full]) (3.0.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (6.5.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (6.1.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (5.4.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.8.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.1->moto>=3.0.7; extra == "full"->pycaret[full]) (2.21)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.9/dist-packages (from daal==2023.1.0->daal4py==2023.1.0->scikit-learn-intelex>=2023.0.1; (platform_machine == "x86_64" or platform_machine == "AMD64") and extra == "full"->pycaret[full]) (2021.9.0)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.9/dist-packages (from fs->triad>=0.8.4->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (1.4.4)
# Requirement already satisfied: locket in /usr/local/lib/python3.9/dist-packages (from partd>=0.3.10->dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (1.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed==2022.12.1; extra == "distributed"->dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (1.7.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from distributed==2022.12.1; extra == "distributed"->dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (2.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.9/dist-packages (from distributed==2022.12.1; extra == "distributed"->dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (2.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow<2.0.0,>=1.24.0; extra == "full"->pycaret[full]) (5.0.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.7.4->pandas-profiling>=3.1.0; extra == "full"->pycaret[full]) (1.4.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.9/dist-packages (from linkify-it-py<3,>=1; extra == "linkify"->markdown-it-py[linkify]>=2.0.0->gradio>=2.8.10; extra == "full"->pycaret[full]) (1.0.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.9/dist-packages (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (1.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0; extra == "testing"->dash[testing]; extra == "full"->pycaret[full]) (1.2.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.9/dist-packages (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (0.19.3)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.9/dist-packages (from gevent>=1.3.6; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (4.6)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.9/dist-packages (from gevent>=1.3.6; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (6.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->panel~=0.12.6->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.5.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.7.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (0.2.2)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from qtconsole->jupyter->autoviz>=0.1.36; extra == "full"->pycaret[full]) (2.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (21.2.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from zict>=0.1.3->distributed==2022.12.1; extra == "distributed"->dask[dataframe,distributed]>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]>=0.8.0; extra == "full"->pycaret[full]) (1.0.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.3.2->interpret>=0.2.7; extra == "full"->pycaret[full]) (2023.3.21)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from pycaret.classification import *
# %matplotlib inline
warnings.filterwarnings('ignore')
df = pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df = df.drop(columns=['id', 'Unnamed: 32'], axis=1)
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %%
df_temp = df.drop(columns=['diagnosis'], axis=1)

fig, ax = plt.subplots(ncols=6, nrows=5, figsize=(20, 20))
index = 0
ax = ax.flatten()

for col in df_temp.columns:
    sns.distplot(df[col], ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
fig, ax = plt.subplots(ncols=6, nrows=5, figsize=(20, 20))
index = 0
ax = ax.flatten()

for col in df_temp.columns:
    sns.boxplot(y=col, data=df, ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
clf = setup(df, target='diagnosis')
# Out:
# <style type="text/css">
# #T_64fcf_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64fcf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64fcf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64fcf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64fcf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64fcf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64fcf_row0_col1" class="data row0 col1" >3088</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64fcf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64fcf_row1_col1" class="data row1 col1" >diagnosis</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64fcf_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_64fcf_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64fcf_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_64fcf_row3_col1" class="data row3 col1" >B: 0, M: 1</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64fcf_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_64fcf_row4_col1" class="data row4 col1" >(569, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64fcf_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_64fcf_row5_col1" class="data row5 col1" >(569, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64fcf_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_64fcf_row6_col1" class="data row6 col1" >(398, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64fcf_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_64fcf_row7_col1" class="data row7 col1" >(171, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64fcf_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_64fcf_row8_col1" class="data row8 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64fcf_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_64fcf_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64fcf_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_64fcf_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64fcf_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_64fcf_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64fcf_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_64fcf_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64fcf_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_64fcf_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64fcf_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_64fcf_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64fcf_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_64fcf_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64fcf_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_64fcf_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_64fcf_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_64fcf_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_64fcf_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_64fcf_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_64fcf_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_64fcf_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_64fcf_row19_col1" class="data row19 col1" >6ed6</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = create_model('catboost')
# Out:
# <style type="text/css">
# #T_e3fcc_row10_col0, #T_e3fcc_row10_col1, #T_e3fcc_row10_col2, #T_e3fcc_row10_col3, #T_e3fcc_row10_col4, #T_e3fcc_row10_col5, #T_e3fcc_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e3fcc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3fcc_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e3fcc_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e3fcc_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e3fcc_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e3fcc_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e3fcc_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e3fcc_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3fcc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3fcc_row0_col0" class="data row0 col0" >0.9750</td>
#       <td id="T_e3fcc_row0_col1" class="data row0 col1" >0.9973</td>
#       <td id="T_e3fcc_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_e3fcc_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_e3fcc_row0_col4" class="data row0 col4" >0.9655</td>
#       <td id="T_e3fcc_row0_col5" class="data row0 col5" >0.9459</td>
#       <td id="T_e3fcc_row0_col6" class="data row0 col6" >0.9473</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3fcc_row1_col0" class="data row1 col0" >0.9500</td>
#       <td id="T_e3fcc_row1_col1" class="data row1 col1" >0.9707</td>
#       <td id="T_e3fcc_row1_col2" class="data row1 col2" >0.8667</td>
#       <td id="T_e3fcc_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_e3fcc_row1_col4" class="data row1 col4" >0.9286</td>
#       <td id="T_e3fcc_row1_col5" class="data row1 col5" >0.8904</td>
#       <td id="T_e3fcc_row1_col6" class="data row1 col6" >0.8958</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3fcc_row2_col0" class="data row2 col0" >0.9750</td>
#       <td id="T_e3fcc_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_e3fcc_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_e3fcc_row2_col3" class="data row2 col3" >0.9375</td>
#       <td id="T_e3fcc_row2_col4" class="data row2 col4" >0.9677</td>
#       <td id="T_e3fcc_row2_col5" class="data row2 col5" >0.9474</td>
#       <td id="T_e3fcc_row2_col6" class="data row2 col6" >0.9487</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3fcc_row3_col0" class="data row3 col0" >0.9750</td>
#       <td id="T_e3fcc_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_e3fcc_row3_col2" class="data row3 col2" >0.9333</td>
#       <td id="T_e3fcc_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_e3fcc_row3_col4" class="data row3 col4" >0.9655</td>
#       <td id="T_e3fcc_row3_col5" class="data row3 col5" >0.9459</td>
#       <td id="T_e3fcc_row3_col6" class="data row3 col6" >0.9473</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3fcc_row4_col0" class="data row4 col0" >0.9000</td>
#       <td id="T_e3fcc_row4_col1" class="data row4 col1" >0.9973</td>
#       <td id="T_e3fcc_row4_col2" class="data row4 col2" >0.7333</td>
#       <td id="T_e3fcc_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_e3fcc_row4_col4" class="data row4 col4" >0.8462</td>
#       <td id="T_e3fcc_row4_col5" class="data row4 col5" >0.7746</td>
#       <td id="T_e3fcc_row4_col6" class="data row4 col6" >0.7951</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3fcc_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_e3fcc_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_e3fcc_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_e3fcc_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_e3fcc_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_e3fcc_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_e3fcc_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3fcc_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_e3fcc_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_e3fcc_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_e3fcc_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_e3fcc_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_e3fcc_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_e3fcc_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3fcc_row7_col0" class="data row7 col0" >0.9500</td>
#       <td id="T_e3fcc_row7_col1" class="data row7 col1" >0.9973</td>
#       <td id="T_e3fcc_row7_col2" class="data row7 col2" >0.8667</td>
#       <td id="T_e3fcc_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_e3fcc_row7_col4" class="data row7 col4" >0.9286</td>
#       <td id="T_e3fcc_row7_col5" class="data row7 col5" >0.8904</td>
#       <td id="T_e3fcc_row7_col6" class="data row7 col6" >0.8958</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3fcc_row8_col0" class="data row8 col0" >0.9744</td>
#       <td id="T_e3fcc_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_e3fcc_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_e3fcc_row8_col3" class="data row8 col3" >0.9333</td>
#       <td id="T_e3fcc_row8_col4" class="data row8 col4" >0.9655</td>
#       <td id="T_e3fcc_row8_col5" class="data row8 col5" >0.9451</td>
#       <td id="T_e3fcc_row8_col6" class="data row8 col6" >0.9466</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3fcc_row9_col0" class="data row9 col0" >0.9231</td>
#       <td id="T_e3fcc_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_e3fcc_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_e3fcc_row9_col3" class="data row9 col3" >0.8235</td>
#       <td id="T_e3fcc_row9_col4" class="data row9 col4" >0.9032</td>
#       <td id="T_e3fcc_row9_col5" class="data row9 col5" >0.8404</td>
#       <td id="T_e3fcc_row9_col6" class="data row9 col6" >0.8513</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e3fcc_row10_col0" class="data row10 col0" >0.9622</td>
#       <td id="T_e3fcc_row10_col1" class="data row10 col1" >0.9963</td>
#       <td id="T_e3fcc_row10_col2" class="data row10 col2" >0.9333</td>
#       <td id="T_e3fcc_row10_col3" class="data row10 col3" >0.9694</td>
#       <td id="T_e3fcc_row10_col4" class="data row10 col4" >0.9471</td>
#       <td id="T_e3fcc_row10_col5" class="data row10 col5" >0.9180</td>
#       <td id="T_e3fcc_row10_col6" class="data row10 col6" >0.9228</td>
#     </tr>
#     <tr>
#       <th id="T_e3fcc_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e3fcc_row11_col0" class="data row11 col0" >0.0303</td>
#       <td id="T_e3fcc_row11_col1" class="data row11 col1" >0.0086</td>
#       <td id="T_e3fcc_row11_col2" class="data row11 col2" >0.0843</td>
#       <td id="T_e3fcc_row11_col3" class="data row11 col3" >0.0549</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
